# %%
import pandas as pd

# %%
melb_df = pd.read_csv('data/melb_data_fe.csv')

# %% [markdown]
# # МЕТОД SORT_VALUES()

# %% [markdown]
# Для сортировки значений в DataFrame по значениям одного или нескольких столбцов используется метод sort_values().

# %% [markdown]
# Основные параметры метода sort_values():

# %% [markdown]
# * **by** — имя или список имён столбцов, по значениям которых производится сортировка.
# * **axis** — ось, по которой производится сортировка (0 — строки, 1 — столбцы). По умолчанию сортировка производится по строкам.
# * **ascending** — сортировка по возрастанию (от меньшего к большему). По умолчанию параметр выставлен на True, для сортировки по убыванию (от большего к меньшему) необходимо выставить его на False.
# * **ignore_index** — создаются ли новые индексы в таблице. По умолчанию выставлен на False и сохраняет индексы изначальной таблицы.
# * **inplace** — производится ли замена исходной таблицы на отсортированную. По умолчанию параметр выставлен на False, то есть замены не производится. Чтобы переопределить исходную таблицу на отсортированную, необходимо выставить этот параметр на True.

# %% [markdown]
# ## СОРТИРОВКА ПО ЗНАЧЕНИЯМ ОДНОГО СТОЛБЦА

# %% [markdown]
# Отсортируем таблицу по возрастанию цены объектов недвижимости (Price):

# %%
melb_df.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#              Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 2652   2016-03-09       6.4      3011        1  ...   144.89000
# 1805   2017-02-25       8.9      3162        4  ...   145.02420
# 7303   2016-05-28      13.9      3020        2  ...   144.82660
# 1927   2016-04-06       7.8      3058        3  ...   144.96580
# 7940   2017-08-04       4.6      3122        1  ...   145.03730
# 12666  2017-09-16       5.2      3056        1  ...   144.95188
# 8811   2017-01-07       5.1      3011        1  ...   144.89587
# 8504   2017-04-29       8.2      3012        1  ...   144.86720
# 7293   2016-08-22      13.9      3020        1  ...   144.82720
# 7305   2016-07-30      13.9      3020        2  ...   144.82390
#
#                   Regionname  Propertycount  MeanRoomsSquare AreaRatio  \
# 2652    Western Metropolitan           7570        42.000000  1.000000
# 1805   Southern Metropolitan           2379        17.222222 -0.525994
# 7303    Western Metropolitan           2185        31.500000  0.555556
# 1927   Northern Metropolitan          11204        20.500000 -0.531429
# 7940   Southern Metropolitan          11308        42.000000 -0.437500
# 12666  Northern Metropolitan          11918        42.000000 -0.816860
# 8811    Western Metropolitan           7570         8.666667 -0.071429
# 8504    Western Metropolitan           5058        42.000000  1.000000
# 7293    Western Metropolitan           2185        14.333333 -0.964017
# 7305    Western Metropolitan           2185        25.200000  1.000000
#
#        MonthSale  AgeBuilding WeekdaySale  StreetType  Weekend
# 2652           3            9           2          St        0
# 1805           2           97           5          St        1
# 7303           5           46           5          St        1
# 1927           4          106           2          Rd        0
# 7940           8            8           4          St        0
# 12666          9           47           5          St        1
# 8811           1            4           5          St        1
# 8504           4           47           5          St        1
# 7293           8           41           0          Rd        0
# 7305           7           46           5          St        1
#
# [10 rows x 26 columns]

# %% [markdown]
# А теперь отсортируем таблицу по убыванию (от самой последней до самой первой) даты продажи объекта (Date). Для этого выставим параметр ascending на False:

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#              Suburb  Rooms   Type      Price Method    SellerG        Date  \
# 11144     Northcote      4  house  1955000.0     SP    McGrath  2017-12-08
# 11217  Surrey Hills      3  house  1775000.0     PI     Jellis  2017-12-08
# 11206      St Kilda      4  house  1600000.0     VB       Gary  2017-12-08
# 11207    Strathmore      7  house  2000000.0     SP     Nelson  2017-12-08
# 11208    Strathmore      4  house  1610000.0      S      other  2017-12-08
# ...             ...    ...    ...        ...    ...        ...         ...
# 1555     Camberwell      4  house  2650000.0      S     Jellis  2016-03-09
# 4510       Oak Park      3  house   892000.0      S     Nelson  2016-03-09
# 4388      Northcote      3  house  1200000.0      S     Nelson  2016-03-09
# 6184   Surrey Hills      3  house  1205000.0      S  Fletchers  2016-01-28
# 6183   Surrey Hills      2   unit   813000.0      S  Fletchers  2016-01-28
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# 11144       5.3      3070        4  ...   144.99375  Northern Metropolitan
# 11217      10.2      3127        3  ...   145.08968  Southern Metropolitan
# 11206       5.0      3182        4  ...   144.98324  Southern Metropolitan
# 11207       8.2      3041        7  ...   144.90587   Western Metropolitan
# 11208       8.2      3041        4  ...   144.92243   Western Metropolitan
# ...         ...       ...      ...  ...         ...                    ...
# 1555        7.8      3124        4  ...   145.06860  Southern Metropolitan
# 4510       11.5      3046        3  ...   144.91740  Northern Metropolitan
# 4388        5.5      3070        3  ...   144.99090  Northern Metropolitan
# 6184       11.2      3127        3  ...   145.10060  Southern Metropolitan
# 6183       11.2      3127        2  ...   145.10230  Southern Metropolitan
#
#        Propertycount  MeanRoomsSquare AreaRatio  MonthSale  AgeBuilding  \
# 11144          11364        12.600000  0.923664         12           47
# 11217           5457        15.750000 -0.721854         12           47
# 11206          13240        16.000000 -0.586028         12          107
# 11207           3284        20.882353 -0.262721         12           18
# 11208           3284        24.909091 -0.517181         12           62
# ...              ...              ...       ...        ...          ...
# 1555            8920        18.900000 -0.550535          3          126
# 4510            2651        18.000000 -0.714609          3           46
# 4388           11364        17.857143 -0.264706          3           96
# 6184            5457        18.000000 -0.590909          1           46
# 6183            5457        25.200000  0.076923          1           46
#
#       WeekdaySale  StreetType  Weekend
# 11144           4          St        0
# 11217           4          Rd        0
# 11206           4          St        0
# 11207           4          Rd        0
# 11208           4          St        0
# ...           ...         ...      ...
# 1555            2          Rd        0
# 4510            2          St        0
# 4388            2          St        0
# 6184            3          Rd        0
# 6183            3          Rd        0
#
# [13580 rows x 26 columns]

# %% [markdown]
# ## СОРТИРОВКА ПО ЗНАЧЕНИЯМ НЕСКОЛЬКИХ СТОЛБЦОВ

# %% [markdown]
# Так, например, отсортируем таблицу сначала по возрастанию расстояния от центра города (Distance), а затем — по возрастанию цены объекта (Price). Для того чтобы вывод был более наглядным, выделим каждую десятую строку из столбцов Distance и Price результирующей таблицы:

# %%
melb_df.sort_values(by=['Distance', 'Price'])
# Out:
#           Suburb  Rooms   Type      Price Method    SellerG        Date  \
# 11428  Melbourne      2   unit   387000.0      S      other  2017-07-15
# 12074  Melbourne      2   unit   540000.0     PI  Harcourts  2017-07-29
# 12073  Melbourne      2   unit   565000.0      S      other  2017-07-29
# 10393  Melbourne      2   unit   720000.0      S  Harcourts  2017-05-27
# 9620   Melbourne      2   unit   740000.0     VB      other  2017-06-17
# ...          ...    ...    ...        ...    ...        ...         ...
# 10003      other      4  house   410500.0      S        C21  2017-06-24
# 11470      other      4  house   435000.0      S        C21  2017-07-15
# 11763      other      4  house   643500.0      S        C21  2017-07-22
# 10033      other      4  house   817000.0      S      Raine  2017-06-24
# 13245      other      5  house  1355000.0      S      Raine  2017-09-23
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# 11428       0.0      3000        2  ...   144.96924  Northern Metropolitan
# 12074       0.0      3000        2  ...   144.96908  Northern Metropolitan
# 12073       0.0      3000        2  ...   144.96168  Northern Metropolitan
# 10393       0.0      3000        2  ...   144.96273  Northern Metropolitan
# 9620        0.0      3000        2  ...   144.95452  Northern Metropolitan
# ...         ...       ...      ...  ...         ...                    ...
# 10003      47.3      3810        4  ...   145.45376       Eastern Victoria
# 11470      47.3      3810        4  ...   145.48273       Eastern Victoria
# 11763      47.3      3810        4  ...   145.43698       Eastern Victoria
# 10033      47.4      3431        4  ...   144.68999      Northern Victoria
# 13245      48.1      3438        5  ...   144.58864      Northern Victoria
#
#        Propertycount  MeanRoomsSquare AreaRatio  MonthSale  AgeBuilding  \
# 11428          17496         9.400000  1.000000          7            6
# 12074          17496        25.200000  1.000000          7           67
# 12073          17496        17.000000 -0.022989          7           14
# 10393          17496        17.200000  1.000000          5           41
# 9620           17496        22.600000  1.000000          6           18
# ...              ...              ...       ...        ...          ...
# 10003          17384        12.600000 -0.542650          6           47
# 11470          17384        55.300000  0.000000          7           12
# 11763          17384        30.000000 -0.333333          7            7
# 10033           1475        27.240000 -0.685341          6            6
# 13245            849      3424.230769  0.000169          9           47
#
#       WeekdaySale  StreetType  Weekend
# 11428           5          Pl        1
# 12074           5          St        1
# 12073           5          St        1
# 10393           5          St        1
# 9620            5          St        1
# ...           ...         ...      ...
# 10003           5          Dr        1
# 11470           5          Ct        1
# 11763           5       other        1
# 10033           5       other        1
# 13245           5          Rd        1
#
# [13580 rows x 26 columns]

# %% [markdown]
# Мы получили таблицу, отсортированную по возрастанию расстояния до центра города. Если встречаются объекты недвижимости, у которых расстояние оказывается одинаковым, то внутри такой группы производится сортировка по цене объекта.

# %% [markdown]
# ## КОМБИНИРОВАНИЕ СОРТИРОВКИ С ФИЛЬТРАЦИЕЙ

# %% [markdown]
# А теперь рассмотрим применение сортировки на практике.

# %% [markdown]
# Предположим, компания McGrath поручила нам восстановить хронологию продаж таунхаусов, у которых площадь участка существенно больше площади здания, чтобы понять, как часто компания справляется с таким сложным видом объектов. Объекты, проданные в один и тот же день, мы бы хотели сортировать по значению коэффициента соотношения площадей.

# %% [markdown]
# Найдём информацию о таунхаусах (Type), проданных компанией (SellerG) McGrath, у которых коэффициент соотношения площадей здания и участка (AreaRatio) меньше -0.8. Результат отсортируем по дате продажи (Date) в порядке возрастания, а после проведём сортировку по убыванию коэффициента соотношения площадей. Также обновим старые индексы на новые, установив параметр ignore_index на True. Для наглядности результата выберем из таблицы только столбцы Data и AreaRatio:

# %%
mask1 = melb_df['AreaRatio'] < -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'
melb_df[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#          Date  AreaRatio
# 0  2016-07-26  -0.974922
# 1  2016-09-24  -0.971831
# 2  2016-11-27  -0.953608
# 3  2016-12-11  -0.945946
# 4  2017-08-04  -0.947368
# 5  2017-08-04  -0.970874

# %% [markdown]
# # Практика

# %% [markdown]
# 2.2 Произведите сортировку столбца AreaRatio по убыванию. При этом индексы полученной таблицы замените на новые. Какое значение площади здания находится в строке 1558? Ответ округлите до целого числа.

# %%
melb_df.sort_values(by='AreaRatio', ascending=False, ignore_index=True).loc[1558, 'BuildingArea']
# Out:
# 126.0

# %% [markdown]
# 2.3. Найдите таунхаусы (Type) с количеством жилых комнат (Rooms) больше 2. Отсортируйте полученную таблицу сначала по возрастанию числа комнат, а затем по убыванию средней площади комнат (MeanRoomsSquare). Индексы таблицы замените на новые. Какая цена будет у объекта в строке 18? Ответ запишите в виде целого числа.

# %%
mask1 = melb_df['Type'] == 'townhouse'
mask2 = melb_df['Rooms'] > 2

melb_df[mask1 & mask2].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
).loc[18, 'Price']
# Out:
# 1300000.0
